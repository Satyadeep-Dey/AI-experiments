# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyadeep-Dey/AI-experiments/blob/main/1_1_Reuse_utility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

UTIL_PATH = "/content/drive/MyDrive/colab_utils"
sys.path.insert(0, UTIL_PATH)

# %%
from file_utils import read_text_from_colab_file

# %%
# !ls /content/drive/MyDrive/colab_utils

# %%
contents = read_text_from_colab_file(
    folder_path="Files/Text",
    file_name="example.txt"
)

print(contents)
