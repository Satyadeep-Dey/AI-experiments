# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyadeep-Dey/AI-experiments/blob/main/6_5_Read_Write_to_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Let's Read and Write to a file inside a folder in Google Drive

# %%
# imports

import os
import time
from google.colab import drive
from google.colab import userdata

# %% [markdown]
# **Note :** *It's important to ensure that drive is really mounted otherwise we'll have inconsistent behavior — files may appear to be written, but they don't persist to Drive because the mount wasn't ready.*

# %% [markdown]
# # Function to write text into a file

# %%
def write_text_to_file(folder_path, file_name, write_text):

  # Always mount Drive explicitly when using Google Drive
  drive.mount('/content/drive', force_remount=True)
  print("Drive mounted.")

  # Wait until MyDrive is available
  mydrive_path = '/content/drive/MyDrive'
  while not os.path.exists(mydrive_path):
      print("Waiting for Drive to be ready...")
      time.sleep(1)

  # Create folder path if it doesn't exist
  folder_path = os.path.join(mydrive_path, folder_path) #'Files/Text')
  os.makedirs(folder_path, exist_ok=True)

  # Define file path
  file_path = os.path.join(folder_path, file_name) #'example.txt')

  # Write content to the file
  with open(file_path, 'w') as file:
      file.write(write_text)


  print("File written successfully to:", file_path)

# %% [markdown]
# # Let's try this out

# %%
# Writes to Google Drive
write_text_to_file(
    folder_path="Files/Text",
    file_name="example.txt",
    write_text="Hello, cross-platform world! How are youuu doiiiinnnnng !!"
)

# %% [markdown]
# # Function to read from a file

# %%
def read_text_from_file(folder_path, file_name):

  # Always mount Drive explicitly when using Google Drive
  drive.mount('/content/drive', force_remount=True)
  print("Drive mounted.")

  # Wait until MyDrive is available
  mydrive_path = '/content/drive/MyDrive'
  while not os.path.exists(mydrive_path):
      print("Waiting for Drive to be ready...")
      time.sleep(1)

  # Path to the file
  file_path = os.path.join(mydrive_path, folder_path, file_name) #'Files/Text/example.txt')

  # Check if the file exists
  if os.path.exists(file_path):
      # Read the content of the file
      with open(file_path, 'r') as file:
          contents = file.read()
      return contents
  else:
      return "File not found!"

# %% [markdown]
# # Let's try this out

# %%
contents = read_text_from_file(
    folder_path="Files/Text",
    file_name="audio_file_name_202504181127.txt"
)

print("File contents:")
print(contents)
